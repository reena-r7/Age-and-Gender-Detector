# %%
from cv2 import cv2
from matplotlib import pyplot as plt

# %%
#PLotting

# %%
img1 = cv2.imread("Resources/12.jpg",0)

# %%
plt.imshow(img1)

# %%
#arithmetic operations

# %%
img2 = cv2.imread("Resources/12.jpg",0)

# %%
result=img1+img2
#addition

# %%
plt.imshow(result)

# %%
#subtraction
result = img1-img2

# %%
plt.imshow(result)

# %%
# # multiplication

# %%
result = img1*img2

# %%
plt.imshow(result)

# %%
#division
result = img1/img2
plt.imshow(result)
# Out:
# <ipython-input-27-339eb870c4eb>:2: RuntimeWarning: invalid value encountered in true_divide
#   result = img1/img2

# %%
#blurred
img1=cv2.imread("Resources/12.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result= cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2BGR)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
#zoom
img1 = cv2.imread("Resources/12.jpg",0)

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
#another way
result=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(result)

# %%
#rotate need matrix
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
#translate or moving image to certain point
#need numpy for this
import numpy as np

# %%
#define m as a floating array
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
